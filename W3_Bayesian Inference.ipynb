# %%
#Name: Chaeyoon Kim
#City Email: Chaeyoon.Kim@city.ac.uk

from IPython.display import Image

# %% [markdown]
# There are 2 different ways of thinking about probability. Whenever I look over the probability, there are always 2 key concepts, data and parameters.
#
# ## Frequentist vs. Baysian
#
# The frequentist believes that parameters are not random, but data is random (Bishop, p.22). <br>
# Let’s suppose random variable $X$ = height of person in the UK, for example, then the frequentist believes the height is random but the mean and variance of the height of person in the UK are fixed (just imagine the higher person like GOD, knows everything!).
#
# So, there is a normal distribution with the mean and variance which these heights come from. If you just go outside and measure someone’s height, that would be a height from your random observation in the normal distribution. This is what a frequentist approaches that the parameters(mean and variance) are fixed having random data(variable).
#
# In the other word, the bayesian believes that parameters are random, but data is fixed. The differences between these two approaches can be simplified to say that the Bayesian only believes what they can see. They only trust things they can see.
#
# Therefore, the data is exchangeable when your observation has changed, but the parameters are random because they can’t observe (only GOD knows).

# %% [markdown]
# Here is a question from a ***frequentist, because my data is random, what is the probability of observing my data?*** However, a ***Bayesian would ask, because my parameters are random, what is the probability of observing these parameters?***
#
# This is same that what is the probability of data in the given parameters, $P(\text{data}|\text{parameters})$, for frequentist approach. And $P(\text{parameters}|\text{data})$ for bayesian approach. <br>
#
# Here, $P(\text{parameters}|\text{data})$=$P(\text{data}|\text{parameters}) \times P(\text{parameters})$, where $P(\text{parameters})$ is the ***prior*** and $P(\text{data}|\text{parameters})$ is the ***likelihood***. Because we are thinking of the data in the given parameters which details the given information, then we know $P(\text{parameters})$ as a given information which would be prior knowledge. That is why it is called prior(means before seeing anything, before any information). In the case of $P(\text{data}|\text{parameters})$, likelihood is saying what is the probability of my data would be in the given parameters. If I observe 10 persons height, how likely my data(i.e., 10 height sample) would be in the distribution of the fixed parameters, mean=6 and variance=1? What is the probability to observe my data in the mean=6 and variance=1? <br>
#
#
# As I see in the normal distribution graph below, if my data is in the middle part of the graph means more likely to be observed and if my data is in the tail part of the graph means less likely to be observed.

# %%
Image("Pre Maths session part2.jpg")

# %% [markdown]
# For example, if I have my data = $[5, 2, 3, 2, 1, \cdots ]$, would you say my data is likely in the normal distribution of mean(6) and variance(7)? No. But, if I tell you the mean is 1(or even 2) and variance is 1, is it more likely? Yes.
#
# Now, do you see how the function $P$( height = $[5, 2, 3, 2, 1, … ]$ | mean = 6, variance = 7) is the function of the parameters. My data hasn’t changed. I have observed the height and have already collected the sample result. But for different mean and variance of the height, the output result of the probability function $P(\text{data}|\text{parameters})$ would be changed.

# %% [markdown]
# Likelihood $L$(parameters) = $P$(data|parameters) => Posterior = Likelihood $\times$ Prior

# %% [markdown]
# ### Tutorial 4 MATLAB
#
# sample1 = height 6, weight 130, foot size 8 <br>
# P(C=male|sample1) = P(c=male) $\times$ P(height 6|male) $\times$ P(weight 130|male) $\times$ P(foot size 8|male) <br>
# => pM*prod(normpdf(sample1, meanXM, sqrt(varianceXM)))

# %% [markdown]
# ## The Bayesian framework
#
# our level of confidence
# toss coin 1 and head, p(heads)=1?
# assume "prior" distribution, uniform? different?

# %% [markdown]
# X = outcome of a coin toss, p = proability of success <br>
# X ~ Bernoulli(p) <br>
# P(X = x) = p^x * (1-p)^(1-x) <br>
# Prior = P(p) = 1 <br>
#
# When I toss the coin once, X = 1(heads) <br>
# P(p|X=1) = P(X=1|p) * P(p) <br>
#          = p * 1  <br>
#          = p <br>
# Now we have P(p)=p. <br><br>
#
# Trial2: I toss the coin again, X = 0(tails) <br>
# P(p|X=0) = P(X=0|p) * P(p) <br>
#          = (1-p) * p <br>
# Now we have P(p)=(1-p)*p <br>
#
# Trial3: I toss the coin again, X = 0(tails) <br>
# P(p|X=0) = P(X=0|p) * P(p) <br>
#          = (1-p) * (1-p)*p <br>
# Now we have P(p)= (1-p)^2 * p <br>
#
# ...<br>
# In the same way, <br>
# X = number of heads after 10 tosses, p = proability of success <br>
# X ~ Binom(10, p) <br>
# P(X=x) = (10 x) * p^x * (1 - p) ^ (10-x) <br>
# Prior = P(p) = 1 <br>
#
# if I tossed the coin 10 times, and take x = 4(heads) <br>
# P(X=4) = (10 4) * p^4 * (1 - p) ^ (6) <br>
# posterior = (10 4) * p^4 * ( 1 - p) ^ (6) * 1 <br>

# %%
Image("Tutorial1_Some tips for task 1.png")
